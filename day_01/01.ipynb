# %% [markdown]
# # Exploration
#
# In this document, I'll explore the problem interactively.

# %%
import pandas as pd

# %%
# Read the text file into a dataframe
df = pd.read_csv('input.txt', header=None, names=['Text'])

# Display the dataframe
df
# Out:
#                                     Text
# 0                      gsjgklneight6zqfz
# 1                 7one718onegfqtdbtxfcmd
# 2                             xvtfhkm8c9
# 3                                914two8
# 4    vxzzvdhfqfsix83c1ttvbbstxgdrkfcnmm3
# ..                                   ...
# 995       5onesixsevenphxtmlqhzfcjxrknpv
# 996                  gldsixrhss186seven6
# 997                              gnpksz4
# 998                                 4919
# 999                                pbc19
#
# [1000 rows x 1 columns]

# %%
# Add a column to the dataframe that indicates if the text contains at least two digits
df['ContainsDigits'] = df['Text'].str.contains(r'\d.*\d')
df
# Out:
#                                     Text  ContainsDigits
# 0                      gsjgklneight6zqfz           False
# 1                 7one718onegfqtdbtxfcmd            True
# 2                             xvtfhkm8c9            True
# 3                                914two8            True
# 4    vxzzvdhfqfsix83c1ttvbbstxgdrkfcnmm3            True
# ..                                   ...             ...
# 995       5onesixsevenphxtmlqhzfcjxrknpv           False
# 996                  gldsixrhss186seven6            True
# 997                              gnpksz4           False
# 998                                 4919            True
# 999                                pbc19            True
#
# [1000 rows x 2 columns]

# %%
def get_coordinate(row):
    if row['ContainsDigits']:
        digits = [char for char in row['Text'] if char.isdigit()]
        if digits:
            return digits[0] + digits[-1]
    return ''

df['Coordinate'] = df.apply(get_coordinate, axis=1)
df
# Out:
#                                     Text  ContainsDigits Coordinate
# 0                      gsjgklneight6zqfz           False
# 1                 7one718onegfqtdbtxfcmd            True         78
# 2                             xvtfhkm8c9            True         89
# 3                                914two8            True         98
# 4    vxzzvdhfqfsix83c1ttvbbstxgdrkfcnmm3            True         83
# ..                                   ...             ...        ...
# 995       5onesixsevenphxtmlqhzfcjxrknpv           False
# 996                  gldsixrhss186seven6            True         16
# 997                              gnpksz4           False
# 998                                 4919            True         49
# 999                                pbc19            True         19
#
# [1000 rows x 3 columns]

# %%
# Check if there are any rows that don't contain any digits
no_digits_rows = not df['Text'].str.contains(r'\d').all()
no_digits_rows
# Out:
# False

# %%
def get_coordinate(row):
    if not row['ContainsDigits']:
        digits = [char for char in row['Text'] if char.isdigit()]
        if digits:
            return int(f"{digits[0]}{digits[0]}")
    return row['Coordinate']  # Keep the existing value if present

df['Coordinate'] = df.apply(get_coordinate, axis=1)
df
# Out:
#                                     Text  ContainsDigits Coordinate
# 0                      gsjgklneight6zqfz           False         66
# 1                 7one718onegfqtdbtxfcmd            True         78
# 2                             xvtfhkm8c9            True         89
# 3                                914two8            True         98
# 4    vxzzvdhfqfsix83c1ttvbbstxgdrkfcnmm3            True         83
# ..                                   ...             ...        ...
# 995       5onesixsevenphxtmlqhzfcjxrknpv           False         55
# 996                  gldsixrhss186seven6            True         16
# 997                              gnpksz4           False         44
# 998                                 4919            True         49
# 999                                pbc19            True         19
#
# [1000 rows x 3 columns]

# %%
coordinate_types = df['Coordinate'].apply(type)
print(coordinate_types)
# Out:
# 0      <class 'int'>
# 1      <class 'str'>
# 2      <class 'str'>
# 3      <class 'str'>
# 4      <class 'str'>
#            ...
# 995    <class 'int'>
# 996    <class 'str'>
# 997    <class 'int'>
# 998    <class 'str'>
# 999    <class 'str'>
# Name: Coordinate, Length: 1000, dtype: object

# %%
df['Coordinate'] = df['Coordinate'].astype(int)

# %%
df.Coordinate.sum()
# Out:
# 55108

# %% [markdown]
# This answer is too low according to the site. Time to find out where did I make a mistake.

# %%
for index, row in df.iterrows():
    print(row)
# Out:
# Text              gsjgklneight6zqfz
# ContainsDigits                False
# Coordinate                       66
# Name: 0, dtype: object
# Text              7one718onegfqtdbtxfcmd
# ContainsDigits                      True
# Coordinate                            78
# Name: 1, dtype: object
# Text              xvtfhkm8c9
# ContainsDigits          True
# Coordinate                89
# Name: 2, dtype: object
# Text              914two8
# ContainsDigits       True
# Coordinate             98
# Name: 3, dtype: object
# Text              vxzzvdhfqfsix83c1ttvbbstxgdrkfcnmm3
# ContainsDigits                                   True
# Coordinate                                         83
# Name: 4, dtype: object
# Text              76mkvhmbkpm
# ContainsDigits           True
# Coordinate                 76
# Name: 5, dtype: object
# Text              8sixssmlzlhrnineggmrvg6
# ContainsDigits                       True
# Coordinate                             86
# Name: 6, dtype: object
# Text              threeninedtr7219
# ContainsDigits                True
# Coordinate                      79
# Name: 7, dtype: object
# Text              two2geight
# ContainsDigits         False
# Coordinate                22
# Name: 8, dtype: object
# Text              3nine9fivetwo9twohxhc8
# ContainsDigits                      True
# Coordinate                            38
# Name: 9, dtype: object
# Text              llbfmnzzntdcfbslcl3xxvz
# ContainsDigits                      False
# Coordinate                             33
# Name: 10, dtype: object
# Text              two3leighttvpkfmjhhonefour
# ContainsDigits                         False
# Coordinate                                33
# Name: 11, dtype: object
# Text              1b9four
# ContainsDigits       True
# Coordinate             19
# Name: 12, dtype: object
# Text              fivefdlqonesj2six
# ContainsDigits                False
# Coordinate                       22
# Name: 13, dtype: object
# Text              hfptgztwosix8
# ContainsDigits            False
# Coordinate                   88
# Name: 14, dtype: object
# Text              fourkcxqfgxbsvjj3472
# ContainsDigits                    True
# Coordinate                          32
# Name: 15, dtype: object
# Text              xhzs7rdphtxhtwo
# ContainsDigits              False
# Coordinate                     77
# Name: 16, dtype: object
# Text              eightthree51
# ContainsDigits            True
# Coordinate                  51
# Name: 17, dtype: object
# Text              3nmronemlqzfxgonepkh
# ContainsDigits                   False
# Coordinate                          33
# Name: 18, dtype: object
# Text              9vnxqtjjrsg
# ContainsDigits          False
# Coordinate                 99
# Name: 19, dtype: object
# Text              533fivesixrvqfxjrdhl
# ContainsDigits                    True
# Coordinate                          53
# Name: 20, dtype: object
# Text              bkrljtkjb42fqnp
# ContainsDigits               True
# Coordinate                     42
# Name: 21, dtype: object
# Text              4mrh734
# ContainsDigits       True
# Coordinate             44
# Name: 22, dtype: object
# Text              threefourfive83l
# ContainsDigits                True
# Coordinate                      83
# Name: 23, dtype: object
# Text              lcjftnpqfourfivesixtwof3
# ContainsDigits                       False
# Coordinate                              33
# Name: 24, dtype: object
# Text              sevennineh7two3
# ContainsDigits               True
# Coordinate                     73
# Name: 25, dtype: object
# Text              onecgrmb74ctxhg
# ContainsDigits               True
# Coordinate                     74
# Name: 26, dtype: object
# Text              kmvtdrxvrfivethree2
# ContainsDigits                  False
# Coordinate                         22
# Name: 27, dtype: object
# Text              seven98mflv
# ContainsDigits           True
# Coordinate                 98
# Name: 28, dtype: object
# Text              tmoneightzstdjqjncnkpkknzoneonethreefive7
# ContainsDigits                                        False
# Coordinate                                               77
# Name: 29, dtype: object
# Text              fourzsqjbffmxf6lsqdttjfive1nine
# ContainsDigits                               True
# Coordinate                                     61
# Name: 30, dtype: object
# Text              ccs3onesgmmrb
# ContainsDigits            False
# Coordinate                   33
# Name: 31, dtype: object
# Text              kflkpscthreehjjgckfrfdhc3krgntwofour
# ContainsDigits                                   False
# Coordinate                                          33
# Name: 32, dtype: object
# Text              7five2134
# ContainsDigits         True
# Coordinate               74
# Name: 33, dtype: object
# Text              pnfbrjhgprdsvzjrklrclmlgkk69four4
# ContainsDigits                                 True
# Coordinate                                       64
# Name: 34, dtype: object
# Text              cheightwofourxt2
# ContainsDigits               False
# Coordinate                      22
# Name: 35, dtype: object
# Text              1167threetfqstpkc
# ContainsDigits                 True
# Coordinate                       17
# Name: 36, dtype: object
# Text              6dsk2bhqmonejggkpvffhgnrbsix
# ContainsDigits                            True
# Coordinate                                  62
# Name: 37, dtype: object
# Text              five9threefour
# ContainsDigits             False
# Coordinate                    99
# Name: 38, dtype: object
# Text              one3136four
# ContainsDigits           True
# Coordinate                 36
# Name: 39, dtype: object
# Text              vvncdsg6jnxlbsb3
# ContainsDigits                True
# Coordinate                      63
# Name: 40, dtype: object
# Text              fgftp5
# ContainsDigits     False
# Coordinate            55
# Name: 41, dtype: object
# Text              xxscpztpxteightv4mprlzmdhxtxmpvgfour
# ContainsDigits                                   False
# Coordinate                                          44
# Name: 42, dtype: object
# Text                 g4
# ContainsDigits    False
# Coordinate           44
# Name: 43, dtype: object
# Text              eightmbqbrxjbdx5
# ContainsDigits               False
# Coordinate                      55
# Name: 44, dtype: object
# Text              8nineeighttwo6lcsvmvxdqbgpdbtjnnine
# ContainsDigits                                   True
# Coordinate                                         86
# Name: 45, dtype: object
# Text              jkj86threeskgpnl3four
# ContainsDigits                     True
# Coordinate                           83
# Name: 46, dtype: object
# Text              rtmpn5cbtthreefgxnhhvlkxcbtknnine
# ContainsDigits                                False
# Coordinate                                       55
# Name: 47, dtype: object
# Text              7dpn6cqstqrv7sbgzxhgrqrgn
# ContainsDigits                         True
# Coordinate                               77
# Name: 48, dtype: object
# Text              3fivetxgjgndz1
# ContainsDigits              True
# Coordinate                    31
# Name: 49, dtype: object
# Text              tfmkd8three2
# ContainsDigits            True
# Coordinate                  82
# Name: 50, dtype: object
# Text              rcl55cvnfour9twofive
# ContainsDigits                    True
# Coordinate                          59
# Name: 51, dtype: object
# Text              dmgdbkfjvsnpctj69four5
# ContainsDigits                      True
# Coordinate                            65
# Name: 52, dtype: object
# Text              xjlrvznbgl78eight
# ContainsDigits                 True
# Coordinate                       78
# Name: 53, dtype: object
# Text              dmhkvgbc6four6eightwofkk
# ContainsDigits                        True
# Coordinate                              66
# Name: 54, dtype: object
# Text              zlhzn898scffour
# ContainsDigits               True
# Coordinate                     88
# Name: 55, dtype: object
# Text              bdeighttxntvnslbf1nine59
# ContainsDigits                        True
# Coordinate                              19
# Name: 56, dtype: object
# Text              htjltzmzeight5foureightdvv
# ContainsDigits                         False
# Coordinate                                55
# Name: 57, dtype: object
# Text              45fourl2
# ContainsDigits        True
# Coordinate              42
# Name: 58, dtype: object
# Text              seventhree39fivesixtwokchzgc
# ContainsDigits                            True
# Coordinate                                  39
# Name: 59, dtype: object
# Text              fxtbgsxch1lmdsldthreefour8rkxjz9
# ContainsDigits                                True
# Coordinate                                      19
# Name: 60, dtype: object
# Text              five3five8
# ContainsDigits          True
# Coordinate                38
# Name: 61, dtype: object
# Text              threefvfcxnfgskqjdjknrgkvnkl6
# ContainsDigits                            False
# Coordinate                                   66
# Name: 62, dtype: object
# Text              8jzdkxm
# ContainsDigits      False
# Coordinate             88
# Name: 63, dtype: object
# Text              plttwo2fourseven99zthrklvcvp
# ContainsDigits                            True
# Coordinate                                  29
# Name: 64, dtype: object
# Text              gxjfdnzrcj2847eightnine
# ContainsDigits                       True
# Coordinate                             27
# Name: 65, dtype: object
# Text              2onetwoxdc
# ContainsDigits         False
# Coordinate                22
# Name: 66, dtype: object
# Text              35zlpzpvfn77
# ContainsDigits            True
# Coordinate                  37
# Name: 67, dtype: object
# Text              nxppmskvrd1one89eightfive
# ContainsDigits                         True
# Coordinate                               19
# Name: 68, dtype: object
# Text              glhp52f
# ContainsDigits       True
# Coordinate             52
# Name: 69, dtype: object
# Text              mpptktkhrbbcsdheighteightqkjgckvxs6fourseven
# ContainsDigits                                           False
# Coordinate                                                  66
# Name: 70, dtype: object
# Text              1ninelspvpm
# ContainsDigits          False
# Coordinate                 11
# Name: 71, dtype: object
# Text              threefqn551
# ContainsDigits           True
# Coordinate                 51
# Name: 72, dtype: object
# Text              eight95lhxrtwoh2hbnd
# ContainsDigits                    True
# Coordinate                          92
# Name: 73, dtype: object
# Text              jlbclhxp72fivektxfxbtwonetxl
# ContainsDigits                            True
# Coordinate                                  72
# Name: 74, dtype: object
# Text              one7nflzdbdjchbbqqmn
# ContainsDigits                   False
# Coordinate                          77
# Name: 75, dtype: object
# Text              fivesbgsrvzrhz2ncbkhsbrgnpbkgcsrln1zksfqkcxpf
# ContainsDigits                                             True
# Coordinate                                                   21
# Name: 76, dtype: object
# Text              1ftfour22hvdcqrseven
# ContainsDigits                    True
# Coordinate                          12
# Name: 77, dtype: object
# Text              sevenjgrkpbxxnnv1nine6hzkrzzfl
# ContainsDigits                              True
# Coordinate                                    16
# Name: 78, dtype: object
# Text              fourthreefour98sevenbthreesix
# ContainsDigits                             True
# Coordinate                                   98
# Name: 79, dtype: object
# Text              sixgrrjkl3gdzz86onejpjlbpnthree
# ContainsDigits                               True
# Coordinate                                     36
# Name: 80, dtype: object
# Text              vhx3tnzcjvgg
# ContainsDigits           False
# Coordinate                  33
# Name: 81, dtype: object
# Text              six3one4sixeighttwosbkqdjfhfroneights
# ContainsDigits                                     True
# Coordinate                                           34
# Name: 82, dtype: object
# Text              669eighteight32seven
# ContainsDigits                    True
# Coordinate                          62
# Name: 83, dtype: object
# Text              jdpzkdnngc6bvqvtxtxfivesixthreedndsqmv
# ContainsDigits                                     False
# Coordinate                                            66
# Name: 84, dtype: object
# Text              9eight6ssxcdt6fivedsnine
# ContainsDigits                        True
# Coordinate                              96
# Name: 85, dtype: object
# Text              nine3onetjmdqpktwo
# ContainsDigits                 False
# Coordinate                        33
# Name: 86, dtype: object
# Text              ninejjzrklhptsdzbt6tmxnpbrm
# ContainsDigits                          False
# Coordinate                                 66
# Name: 87, dtype: object
# Text              eightsevensixtxvxlqtdjfivebnvpdhvfsqbbssfkplzm...
# ContainsDigits                                                False
# Coordinate                                                       77
# Name: 88, dtype: object
# Text              xmeightone5cjgn1nhjsthree5
# ContainsDigits                          True
# Coordinate                                55
# Name: 89, dtype: object
# Text              xncbclzqqgskthree14bptlrknkmpntxmnf
# ContainsDigits                                   True
# Coordinate                                         14
# Name: 90, dtype: object
# Text              sevenfour8
# ContainsDigits         False
# Coordinate                88
# Name: 91, dtype: object
# Text                34
# ContainsDigits    True
# Coordinate          34
# Name: 92, dtype: object
# Text              5ccslrvbfive
# ContainsDigits           False
# Coordinate                  55
# Name: 93, dtype: object
# Text              sixsixlqf72
# ContainsDigits           True
# Coordinate                 72
# Name: 94, dtype: object
# Text              kknmskkfivezcmjrgfgclgrz1
# ContainsDigits                        False
# Coordinate                               11
# Name: 95, dtype: object
# Text              gqxtmrsqxfour12vlonefive
# ContainsDigits                        True
# Coordinate                              12
# Name: 96, dtype: object
# Text              four8594kxsc
# ContainsDigits            True
# Coordinate                  84
# Name: 97, dtype: object
# Text               364
# ContainsDigits    True
# Coordinate          34
# Name: 98, dtype: object
# Text              hrbfxdpfivesevenjcjdm3nine9sixsh
# ContainsDigits                                True
# Coordinate                                      39
# Name: 99, dtype: object
# Text              mml5five
# ContainsDigits       False
# Coordinate              55
# Name: 100, dtype: object
# Text              btcqdx7jjsix
# ContainsDigits           False
# Coordinate                  77
# Name: 101, dtype: object
# Text              4558seven4mjzsix
# ContainsDigits                True
# Coordinate                      44
# Name: 102, dtype: object
# Text              1mfckqcfk
# ContainsDigits        False
# Coordinate               11
# Name: 103, dtype: object
# Text              4pjtbd18ghnnjqmjm6cvcdgjlcrmxpnnts
# ContainsDigits                                  True
# Coordinate                                        46
# Name: 104, dtype: object
# Text              eight6hd
# ContainsDigits       False
# Coordinate              66
# Name: 105, dtype: object
# Text              cdjdhpjccncpmrfour9qxlqfivenxjfssftnq
# ContainsDigits                                    False
# Coordinate                                           99
# Name: 106, dtype: object
# Text              5bchcbpjxnsbkxgbqgbr
# ContainsDigits                   False
# Coordinate                          55
# Name: 107, dtype: object
# Text              sixlhnzzmkbfourhzp58onetwoseven
# ContainsDigits                               True
# Coordinate                                     58
# Name: 108, dtype: object
# Text              kfgkqfivek3br
# ContainsDigits            False
# Coordinate                   33
# Name: 109, dtype: object
# Text              fnklssmgnine4eight
# ContainsDigits                 False
# Coordinate                        44
# Name: 110, dtype: object
# Text              rbbnjvgpkgbs65sevenmeightsevennine
# ContainsDigits                                  True
# Coordinate                                        65
# Name: 111, dtype: object
# Text              8ninenzgpldnfgjjmbqpmqvgqcthree5seven2
# ContainsDigits                                      True
# Coordinate                                            82
# Name: 112, dtype: object
# Text              seven6pdrgrldhtldhmndbjpj
# ContainsDigits                        False
# Coordinate                               66
# Name: 113, dtype: object
# Text              5three4zmjpslhh
# ContainsDigits               True
# Coordinate                     54
# Name: 114, dtype: object
# Text              threesixsix45
# ContainsDigits             True
# Coordinate                   45
# Name: 115, dtype: object
# Text              szxnvzrkseven2tctf
# ContainsDigits                 False
# Coordinate                        22
# Name: 116, dtype: object
# Text              xqzpninesixseven5dndlqd7
# ContainsDigits                        True
# Coordinate                              57
# Name: 117, dtype: object
# Text              three6ghhzcvpkfivervsgplxq
# ContainsDigits                         False
# Coordinate                                66
# Name: 118, dtype: object
# Text              eighttwoeightlfntmxptgk2pngplvr39
# ContainsDigits                                 True
# Coordinate                                       29
# Name: 119, dtype: object
# Text              33ninenine4fivejseven6
# ContainsDigits                      True
# Coordinate                            36
# Name: 120, dtype: object
# Text              fivehxbmjvxxrzrqr29npqhhlsjr2ttmnl
# ContainsDigits                                  True
# Coordinate                                        22
# Name: 121, dtype: object
# Text              slmltqplzl73dxkxrpgn
# ContainsDigits                    True
# Coordinate                          73
# Name: 122, dtype: object
# Text              lxg4371three
# ContainsDigits            True
# Coordinate                  41
# Name: 123, dtype: object
# Text              tjxsmjnthreefive5fivemshrhhj
# ContainsDigits                           False
# Coordinate                                  55
# Name: 124, dtype: object
# Text              5eighttwo
# ContainsDigits        False
# Coordinate               55
# Name: 125, dtype: object
# Text              sixbpqtcrjzmveighteightjzgktzss1
# ContainsDigits                               False
# Coordinate                                      11
# Name: 126, dtype: object
# Text              1qxjz57sixzh
# ContainsDigits            True
# Coordinate                  17
# Name: 127, dtype: object
# Text              4djpqz54122
# ContainsDigits           True
# Coordinate                 42
# Name: 128, dtype: object
# Text              threeclg1ng7kgprvd
# ContainsDigits                  True
# Coordinate                        17
# Name: 129, dtype: object
# Text              3143threenine71
# ContainsDigits               True
# Coordinate                     31
# Name: 130, dtype: object
# Text              kcxmcthreesixeight23
# ContainsDigits                    True
# Coordinate                          23
# Name: 131, dtype: object
# Text              4zhvn4five
# ContainsDigits          True
# Coordinate                44
# Name: 132, dtype: object
# Text              lmxfone47fbdsixjgl
# ContainsDigits                  True
# Coordinate                        47
# Name: 133, dtype: object
# Text              kzcdzp2
# ContainsDigits      False
# Coordinate             22
# Name: 134, dtype: object
# Text              27twozjbtr
# ContainsDigits          True
# Coordinate                27
# Name: 135, dtype: object
# Text              gpvkqdpbpzthreeone5
# ContainsDigits                  False
# Coordinate                         55
# Name: 136, dtype: object
# Text              bqvneightseven8qll
# ContainsDigits                 False
# Coordinate                        88
# Name: 137, dtype: object
# Text              seven8brjrp272none
# ContainsDigits                  True
# Coordinate                        82
# Name: 138, dtype: object
# Text              3kxhglddkjklkl
# ContainsDigits             False
# Coordinate                    33
# Name: 139, dtype: object
# Text              5sevennine52nine
# ContainsDigits                True
# Coordinate                      52
# Name: 140, dtype: object
# Text              3fourgznkfpfsxzsnmoneqsixtsm
# ContainsDigits                           False
# Coordinate                                  33
# Name: 141, dtype: object
# Text              twothreemkz6ttrtbj8
# ContainsDigits                   True
# Coordinate                         68
# Name: 142, dtype: object
# Text              qoneight28fourninempvltzrtzgvfdcdlxv
# ContainsDigits                                    True
# Coordinate                                          28
# Name: 143, dtype: object
# Text              rllmkpvgqnkdgdrseven2five3
# ContainsDigits                          True
# Coordinate                                23
# Name: 144, dtype: object
# Text              7eight89fourlkfourfivejkqgffz
# ContainsDigits                             True
# Coordinate                                   79
# Name: 145, dtype: object
# Text              four6xr
# ContainsDigits      False
# Coordinate             66
# Name: 146, dtype: object
# Text              6sixfive2hhzdkskxnine3nine
# ContainsDigits                          True
# Coordinate                                63
# Name: 147, dtype: object
# Text              two6qmmkhb9eight
# ContainsDigits                True
# Coordinate                      69
# Name: 148, dtype: object
# Text              cqfxnmrlnhcsdqqxkn2nsncgvdxgmnineeight
# ContainsDigits                                     False
# Coordinate                                            22
# Name: 149, dtype: object
# Text              7sixsdsfour4mrxeight
# ContainsDigits                    True
# Coordinate                          74
# Name: 150, dtype: object
# Text              44threetcmtzmxzgjonesixnine8seven
# ContainsDigits                                 True
# Coordinate                                       48
# Name: 151, dtype: object
# Text              dlonethreejh6bgxxmlkdseightwokp
# ContainsDigits                              False
# Coordinate                                     66
# Name: 152, dtype: object
# Text              four3lspkhhtsmone
# ContainsDigits                False
# Coordinate                       33
# Name: 153, dtype: object
# Text              89hjtnrrpvfzjdkzp
# ContainsDigits                 True
# Coordinate                       89
# Name: 154, dtype: object
# Text              xc4sixvzpccdblczvleight7
# ContainsDigits                        True
# Coordinate                              47
# Name: 155, dtype: object
# Text              2twotwogzqhp9vnbp
# ContainsDigits                 True
# Coordinate                       29
# Name: 156, dtype: object
# Text              rxsplmvb1two8pdtnxtbthreefiveeight
# ContainsDigits                                  True
# Coordinate                                        18
# Name: 157, dtype: object
# Text              bsfdmnnj8eight
# ContainsDigits             False
# Coordinate                    88
# Name: 158, dtype: object
# Text              rntszdckhhcmqn21ljzqbhn
# ContainsDigits                       True
# Coordinate                             21
# Name: 159, dtype: object
# Text              nineeight8
# ContainsDigits         False
# Coordinate                88
# Name: 160, dtype: object
# Text              1fhmnzzlfjpdp3ptj8threejqvmstbtp
# ContainsDigits                                True
# Coordinate                                      18
# Name: 161, dtype: object
# Text               267
# ContainsDigits    True
# Coordinate          27
# Name: 162, dtype: object
# Text              hkknsfivecrhthvbhhqj1
# ContainsDigits                    False
# Coordinate                           11
# Name: 163, dtype: object
# Text              six6xcqpnj9fivezcqbrfour4
# ContainsDigits                         True
# Coordinate                               64
# Name: 164, dtype: object
# Text              8one2gfsgg
# ContainsDigits          True
# Coordinate                82
# Name: 165, dtype: object
# Text              mszrrqmr4nine9
# ContainsDigits              True
# Coordinate                    49
# Name: 166, dtype: object
# Text              5fournine43three
# ContainsDigits                True
# Coordinate                      53
# Name: 167, dtype: object
# Text              5one9hvvrthreethreef3
# ContainsDigits                     True
# Coordinate                           53
# Name: 168, dtype: object
# Text              ninetwo6twofivefivennhjqkhzntkqptfxvdj
# ContainsDigits                                     False
# Coordinate                                            66
# Name: 169, dtype: object
# Text              9onetwo5fiveeightnine8
# ContainsDigits                      True
# Coordinate                            98
# Name: 170, dtype: object
# Text              nineseventslmmgnsjbdgsb2sixlmvxpdg6
# ContainsDigits                                   True
# Coordinate                                         26
# Name: 171, dtype: object
# Text              8nineonethreehghh
# ContainsDigits                False
# Coordinate                       88
# Name: 172, dtype: object
# Text              jd1kr
# ContainsDigits    False
# Coordinate           11
# Name: 173, dtype: object
# Text              drrsxljl4
# ContainsDigits        False
# Coordinate               44
# Name: 174, dtype: object
# Text              fqhfjdxdlsgjgkhcpjkqpgzjgchsixrvzqn7
# ContainsDigits                                   False
# Coordinate                                          77
# Name: 175, dtype: object
# Text              7one2qsnxhfqkseven6
# ContainsDigits                   True
# Coordinate                         76
# Name: 176, dtype: object
# Text              1vhljtwo1oneightqm
# ContainsDigits                  True
# Coordinate                        11
# Name: 177, dtype: object
# Text                gl3
# ContainsDigits    False
# Coordinate           33
# Name: 178, dtype: object
# Text              two2eight1threethree
# ContainsDigits                    True
# Coordinate                          21
# Name: 179, dtype: object
# Text              64nine
# ContainsDigits      True
# Coordinate            64
# Name: 180, dtype: object
# Text              qglkhnfffsnine2three566three
# ContainsDigits                            True
# Coordinate                                  26
# Name: 181, dtype: object
# Text              7sixtwo6trbbklgjteighttwo
# ContainsDigits                         True
# Coordinate                               76
# Name: 182, dtype: object
# Text              nkccpeight4sevensevenone
# ContainsDigits                       False
# Coordinate                              44
# Name: 183, dtype: object
# Text              eight9ldkvgqhq3
# ContainsDigits               True
# Coordinate                     93
# Name: 184, dtype: object
# Text              ttkqpxpzrxph1zfzhbvbgvn
# ContainsDigits                      False
# Coordinate                             11
# Name: 185, dtype: object
# Text              46lqxxgrmvsix
# ContainsDigits             True
# Coordinate                   46
# Name: 186, dtype: object
# Text              twosixcqsmjsthree8pqthmd
# ContainsDigits                       False
# Coordinate                              88
# Name: 187, dtype: object
# Text              ninesixdsns66lvnkhrq3
# ContainsDigits                     True
# Coordinate                           63
# Name: 188, dtype: object
# Text              seven413crqjpkfqleightlgxgck
# ContainsDigits                            True
# Coordinate                                  43
# Name: 189, dtype: object
# Text              onesxztkrtxksqklpqcmrlpjlnst6ftwo
# ContainsDigits                                False
# Coordinate                                       66
# Name: 190, dtype: object
# Text              jzb1oneightqqr
# ContainsDigits             False
# Coordinate                    11
# Name: 191, dtype: object
# Text              ninexrmlglbdlfqm4twolnlq
# ContainsDigits                       False
# Coordinate                              44
# Name: 192, dtype: object
# Text              4seven4eightzds
# ContainsDigits               True
# Coordinate                     44
# Name: 193, dtype: object
# Text              fourngdzkklkxtsix8
# ContainsDigits                 False
# Coordinate                        88
# Name: 194, dtype: object
# Text              cggtwonebtkxtwothree16seven
# ContainsDigits                           True
# Coordinate                                 16
# Name: 195, dtype: object
# Text              three59threesix
# ContainsDigits               True
# Coordinate                     59
# Name: 196, dtype: object
# Text              3qfglrfcr4nine
# ContainsDigits              True
# Coordinate                    34
# Name: 197, dtype: object
# Text              9seveneighttwofoureightvvhpgmpnftwo
# ContainsDigits                                  False
# Coordinate                                         99
# Name: 198, dtype: object
# Text              seven2sixvsmxv86
# ContainsDigits                True
# Coordinate                      26
# Name: 199, dtype: object
# Text              mgvqr5two
# ContainsDigits        False
# Coordinate               55
# Name: 200, dtype: object
# Text              lggjffzt2six7vxflh23
# ContainsDigits                    True
# Coordinate                          23
# Name: 201, dtype: object
# Text              hctpninesevenoneonevr3
# ContainsDigits                     False
# Coordinate                            33
# Name: 202, dtype: object
# Text              7threeqzgzm532mn5
# ContainsDigits                 True
# Coordinate                       75
# Name: 203, dtype: object
# Text              vltdnjhxgl6rjbmcb79s69eight
# ContainsDigits                           True
# Coordinate                                 69
# Name: 204, dtype: object
# Text              snkbpcgclpbflxbz6nkktqqgplm11bdnvpfour
# ContainsDigits                                      True
# Coordinate                                            61
# Name: 205, dtype: object
# Text              75dllnlkthree93onedflbbmlvmd
# ContainsDigits                            True
# Coordinate                                  73
# Name: 206, dtype: object
# Text              sixthree94frdpkdccqkxv5
# ContainsDigits                       True
# Coordinate                             95
# Name: 207, dtype: object
# Text              hdpsvxl2bszdpgspqgxrzz3
# ContainsDigits                       True
# Coordinate                             23
# Name: 208, dtype: object
# Text              hztwonethreeeightzjqk8fivepvgrpsrxxsbfqfv
# ContainsDigits                                        False
# Coordinate                                               88
# Name: 209, dtype: object
# Text              kfmh6sixv74two
# ContainsDigits              True
# Coordinate                    64
# Name: 210, dtype: object
# Text              one9three5
# ContainsDigits          True
# Coordinate                95
# Name: 211, dtype: object
# Text              lcn2hls3three66gsfmzvlx
# ContainsDigits                       True
# Coordinate                             26
# Name: 212, dtype: object
# Text              tmlhhl72nhhkppscc
# ContainsDigits                 True
# Coordinate                       72
# Name: 213, dtype: object
# Text              eightsevenprzgonethree7nine1
# ContainsDigits                            True
# Coordinate                                  71
# Name: 214, dtype: object
# Text              1rngfnx78196sixrjbbkzp
# ContainsDigits                      True
# Coordinate                            16
# Name: 215, dtype: object
# Text              6seven2182six
# ContainsDigits             True
# Coordinate                   62
# Name: 216, dtype: object
# Text              fpsl5xbdnjbzonethreezcfqmqonefive
# ContainsDigits                                False
# Coordinate                                       55
# Name: 217, dtype: object
# Text              5cxhrqzsfz34xdkvtxblkhvstcmjc
# ContainsDigits                             True
# Coordinate                                   54
# Name: 218, dtype: object
# Text              seven36ccqzfmmlvsevennine
# ContainsDigits                         True
# Coordinate                               36
# Name: 219, dtype: object
# Text              5nrvq2nine2
# ContainsDigits           True
# Coordinate                 52
# Name: 220, dtype: object
# Text              fljzxvninetqxjjcrsvp7
# ContainsDigits                    False
# Coordinate                           77
# Name: 221, dtype: object
# Text              1ninetwosevenvdtn4qcxnblgx2two
# ContainsDigits                              True
# Coordinate                                    12
# Name: 222, dtype: object
# Text              dcfxp2onefourfive
# ContainsDigits                False
# Coordinate                       22
# Name: 223, dtype: object
# Text              6czxzpsc
# ContainsDigits       False
# Coordinate              66
# Name: 224, dtype: object
# Text              threeone1grvz8pvzvzkdzjfsix
# ContainsDigits                           True
# Coordinate                                 18
# Name: 225, dtype: object
# Text              hmbpnqntczjhdlsjonedr9prxvkt6one9
# ContainsDigits                                 True
# Coordinate                                       99
# Name: 226, dtype: object
# Text              dccns9threeninexgflfjltmvlssrhkbvktcfourg
# ContainsDigits                                        False
# Coordinate                                               99
# Name: 227, dtype: object
# Text              sevenhbflnmglrn4rtseventwo55
# ContainsDigits                            True
# Coordinate                                  45
# Name: 228, dtype: object
# Text              threehddkrvsp11
# ContainsDigits               True
# Coordinate                     11
# Name: 229, dtype: object
# Text              6threegtk5five
# ContainsDigits              True
# Coordinate                    65
# Name: 230, dtype: object
# Text              29m5
# ContainsDigits    True
# Coordinate          25
# Name: 231, dtype: object
# Text              nine3threesixsevennineddgchfiveeightwovqq
# ContainsDigits                                        False
# Coordinate                                               33
# Name: 232, dtype: object
# Text              2jtgvrldnbpfncfxtq
# ContainsDigits                 False
# Coordinate                        22
# Name: 233, dtype: object
# Text              eighttwo6vtgkvpqzthree
# ContainsDigits                     False
# Coordinate                            66
# Name: 234, dtype: object
# Text              5sixseven
# ContainsDigits        False
# Coordinate               55
# Name: 235, dtype: object
# Text              twohj3seven3fourblqqbphcbfive
# ContainsDigits                             True
# Coordinate                                   33
# Name: 236, dtype: object
# Text              6one7twovjfqlsdgnrtzlzmjxgfljs
# ContainsDigits                              True
# Coordinate                                    67
# Name: 237, dtype: object
# Text                1nv
# ContainsDigits    False
# Coordinate           11
# Name: 238, dtype: object
# Text              22five27two
# ContainsDigits           True
# Coordinate                 27
# Name: 239, dtype: object
# Text              3sevenlgeighteight
# ContainsDigits                 False
# Coordinate                        33
# Name: 240, dtype: object
# Text              khpjmtsskfivefivexbjnkdtwogmxcxrqdpl2
# ContainsDigits                                    False
# Coordinate                                           22
# Name: 241, dtype: object
# Text              zmvpjtm6gzgztjrtnmgpsevenfive28vjvhmnr
# ContainsDigits                                      True
# Coordinate                                            68
# Name: 242, dtype: object
# Text              9four71
# ContainsDigits       True
# Coordinate             91
# Name: 243, dtype: object
# Text              9zghgdjs
# ContainsDigits       False
# Coordinate              99
# Name: 244, dtype: object
# Text              3oneqcjhsbv9threefive
# ContainsDigits                     True
# Coordinate                           39
# Name: 245, dtype: object
# Text              47rsggonennqmbbckcdd31three
# ContainsDigits                           True
# Coordinate                                 41
# Name: 246, dtype: object
# Text              sevenfivesixone5eight
# ContainsDigits                    False
# Coordinate                           55
# Name: 247, dtype: object
# Text              48hcmlcone8x6
# ContainsDigits             True
# Coordinate                   46
# Name: 248, dtype: object
# Text              three9threesixjtxhlm3eightgtrskhqfjtgfjbcfdt
# ContainsDigits                                            True
# Coordinate                                                  93
# Name: 249, dtype: object
# Text              5ninefrpqjdhkkcldvhqkljpqpb1
# ContainsDigits                            True
# Coordinate                                  51
# Name: 250, dtype: object
# Text              969nine
# ContainsDigits       True
# Coordinate             99
# Name: 251, dtype: object
# Text              ninenine8ctprmxkvnine3xkl
# ContainsDigits                         True
# Coordinate                               83
# Name: 252, dtype: object
# Text              seven648lpmxdn92
# ContainsDigits                True
# Coordinate                      62
# Name: 253, dtype: object
# Text              rjhvlnz5two
# ContainsDigits          False
# Coordinate                 55
# Name: 254, dtype: object
# Text              dlvqhfmp587
# ContainsDigits           True
# Coordinate                 57
# Name: 255, dtype: object
# Text              sevensix6
# ContainsDigits        False
# Coordinate               66
# Name: 256, dtype: object
# Text              eightsix34fourlgxrndbjjx9mztwo
# ContainsDigits                              True
# Coordinate                                    39
# Name: 257, dtype: object
# Text              czlpflntvpc1qnl2
# ContainsDigits                True
# Coordinate                      12
# Name: 258, dtype: object
# Text              9seven8qsixbjoneeight
# ContainsDigits                     True
# Coordinate                           98
# Name: 259, dtype: object
# Text              snnjcseventwo6qst
# ContainsDigits                False
# Coordinate                       66
# Name: 260, dtype: object
# Text              ndxgj756zqgt
# ContainsDigits            True
# Coordinate                  76
# Name: 261, dtype: object
# Text              krczgjpbfp199three4six
# ContainsDigits                      True
# Coordinate                            14
# Name: 262, dtype: object
# Text              cjeightwoone8
# ContainsDigits            False
# Coordinate                   88
# Name: 263, dtype: object
# Text              ffmddcrh7rrxhpnlkkdl
# ContainsDigits                   False
# Coordinate                          77
# Name: 264, dtype: object
# Text              nine9hhppdvfczxkjninefivecdp
# ContainsDigits                           False
# Coordinate                                  99
# Name: 265, dtype: object
# Text              8eight19
# ContainsDigits        True
# Coordinate              89
# Name: 266, dtype: object
# Text              4fiveeightthree2twotwo
# ContainsDigits                      True
# Coordinate                            42
# Name: 267, dtype: object
# Text              nine2four4941seven
# ContainsDigits                  True
# Coordinate                        21
# Name: 268, dtype: object
# Text              fournine5twodqbkbjjmmqsn
# ContainsDigits                       False
# Coordinate                              55
# Name: 269, dtype: object
# Text              nzqgngfxftwo6
# ContainsDigits            False
# Coordinate                   66
# Name: 270, dtype: object
# Text              5bmlfbsql2sevenjrxkkdtwoone
# ContainsDigits                           True
# Coordinate                                 52
# Name: 271, dtype: object
# Text              jfeightwoppxbpgzdljnmmpvrckv8
# ContainsDigits                            False
# Coordinate                                   88
# Name: 272, dtype: object
# Text              chj66fouronefourvcdd
# ContainsDigits                    True
# Coordinate                          66
# Name: 273, dtype: object
# Text              fourzvgbsgkmgslntrzxtxvjnmhk5v7
# ContainsDigits                               True
# Coordinate                                     57
# Name: 274, dtype: object
# Text              1fnzftqmtj9gqkblpknq6blmlkxbzhdsdljvqfour
# ContainsDigits                                         True
# Coordinate                                               16
# Name: 275, dtype: object
# Text              116rqpdqq
# ContainsDigits         True
# Coordinate               16
# Name: 276, dtype: object
# Text              xslxqcmlchmqlzmkxbk79hnlhthreesnnmnht
# ContainsDigits                                     True
# Coordinate                                           79
# Name: 277, dtype: object
# Text              sixfive8kjhrfdxrtfour
# ContainsDigits                    False
# Coordinate                           88
# Name: 278, dtype: object
# Text              nlv71clmzbnine6
# ContainsDigits               True
# Coordinate                     76
# Name: 279, dtype: object
# Text              42one8lz
# ContainsDigits        True
# Coordinate              48
# Name: 280, dtype: object
# Text              qspsdj2gv6vl8six5
# ContainsDigits                 True
# Coordinate                       25
# Name: 281, dtype: object
# Text              5gctkjzxlr2twoseventhree
# ContainsDigits                        True
# Coordinate                              52
# Name: 282, dtype: object
# Text              rmgmkvqeightpfmrxqmvkg8
# ContainsDigits                      False
# Coordinate                             88
# Name: 283, dtype: object
# Text              3sixnjrjbbzl3
# ContainsDigits             True
# Coordinate                   33
# Name: 284, dtype: object
# Text              1nineseven4three7qhdsxvbmlk
# ContainsDigits                           True
# Coordinate                                 17
# Name: 285, dtype: object
# Text              fourjbznsbgsn2pgxrzlkkjtctm3eight5
# ContainsDigits                                  True
# Coordinate                                        25
# Name: 286, dtype: object
# Text              36fourninecppsqfflbcbljnfgh2
# ContainsDigits                            True
# Coordinate                                  32
# Name: 287, dtype: object
# Text              eight211ninegnfvhfxqcmpmeight
# ContainsDigits                             True
# Coordinate                                   21
# Name: 288, dtype: object
# Text              vbsg73
# ContainsDigits      True
# Coordinate            73
# Name: 289, dtype: object
# Text              3ninetwoonerbzcglkmdg
# ContainsDigits                    False
# Coordinate                           33
# Name: 290, dtype: object
# Text              76ngkrtfonecltwovvgvgznzbmxm
# ContainsDigits                            True
# Coordinate                                  76
# Name: 291, dtype: object
# Text              977eighteightwocp
# ContainsDigits                 True
# Coordinate                       97
# Name: 292, dtype: object
# Text              fxskxcdkdeight2225
# ContainsDigits                  True
# Coordinate                        25
# Name: 293, dtype: object
# Text              seven98rpzjxscseven3vtbbhqjrjfk
# ContainsDigits                               True
# Coordinate                                     93
# Name: 294, dtype: object
# Text              sevenseven97jxh
# ContainsDigits               True
# Coordinate                     97
# Name: 295, dtype: object
# Text              sevenfourfivexsspnqjnlxtbrfour24
# ContainsDigits                                True
# Coordinate                                      24
# Name: 296, dtype: object
# Text              fivefive5two91six
# ContainsDigits                 True
# Coordinate                       51
# Name: 297, dtype: object
# Text              gg2ptrsdxtfjtzztthree8
# ContainsDigits                      True
# Coordinate                            28
# Name: 298, dtype: object
# Text              eight2ncmps1qsix25
# ContainsDigits                  True
# Coordinate                        25
# Name: 299, dtype: object
# Text              eight486zfqfmgchtrrbcrjsevenrcqtxnqnrb
# ContainsDigits                                      True
# Coordinate                                            46
# Name: 300, dtype: object
# Text              7vgn31lvqqvkdqlpddmllbn9
# ContainsDigits                        True
# Coordinate                              79
# Name: 301, dtype: object
# Text              1hlgrlmctseveneight9xfsfseven
# ContainsDigits                             True
# Coordinate                                   19
# Name: 302, dtype: object
# Text              onefourdqzvlh7
# ContainsDigits             False
# Coordinate                    77
# Name: 303, dtype: object
# Text              four543ninethree
# ContainsDigits                True
# Coordinate                      53
# Name: 304, dtype: object
# Text              4seven1one
# ContainsDigits          True
# Coordinate                41
# Name: 305, dtype: object
# Text              79twogmjcngj7rseven3
# ContainsDigits                    True
# Coordinate                          73
# Name: 306, dtype: object
# Text              xxtkcbkgqfldssix4five4nine
# ContainsDigits                          True
# Coordinate                                44
# Name: 307, dtype: object
# Text              tqxnnspd7sevenvljzl2scsbkhqdq
# ContainsDigits                             True
# Coordinate                                   72
# Name: 308, dtype: object
# Text              cbz3rczscjfxtzfivenbjqone
# ContainsDigits                        False
# Coordinate                               33
# Name: 309, dtype: object
# Text              threekkcjlmvkfrsgz6r
# ContainsDigits                   False
# Coordinate                          66
# Name: 310, dtype: object
# Text              1sixvppcksdvrz7
# ContainsDigits               True
# Coordinate                     17
# Name: 311, dtype: object
# Text              dvngzs74eight9
# ContainsDigits              True
# Coordinate                    79
# Name: 312, dtype: object
# Text              qrncqtqxkfrndcrrpjcglfonesix75seven
# ContainsDigits                                   True
# Coordinate                                         75
# Name: 313, dtype: object
# Text              eight6cksxfdthreefive2eight
# ContainsDigits                           True
# Coordinate                                 62
# Name: 314, dtype: object
# Text              four51sixfschln6
# ContainsDigits                True
# Coordinate                      56
# Name: 315, dtype: object
# Text              hblmcggzgqsix2two
# ContainsDigits                False
# Coordinate                       22
# Name: 316, dtype: object
# Text              93two985
# ContainsDigits        True
# Coordinate              95
# Name: 317, dtype: object
# Text              78six6
# ContainsDigits      True
# Coordinate            76
# Name: 318, dtype: object
# Text              6sxmd289nine152
# ContainsDigits               True
# Coordinate                     62
# Name: 319, dtype: object
# Text              gmpdcdcr4xzmhq3
# ContainsDigits               True
# Coordinate                     43
# Name: 320, dtype: object
# Text              5threehpdmq
# ContainsDigits          False
# Coordinate                 55
# Name: 321, dtype: object
# Text              eight54xcrlsv8three4
# ContainsDigits                    True
# Coordinate                          54
# Name: 322, dtype: object
# Text              35twofourfivenine4tjthd
# ContainsDigits                       True
# Coordinate                             34
# Name: 323, dtype: object
# Text              6kch9
# ContainsDigits     True
# Coordinate           69
# Name: 324, dtype: object
# Text              7fjlvptwo2ztrggpmsntwo
# ContainsDigits                      True
# Coordinate                            72
# Name: 325, dtype: object
# Text              7twosix6kmdnvspnqgjxcdtgrspjj7
# ContainsDigits                              True
# Coordinate                                    77
# Name: 326, dtype: object
# Text              tsix8fivethree
# ContainsDigits             False
# Coordinate                    88
# Name: 327, dtype: object
# Text              2pggbgxnft7
# ContainsDigits           True
# Coordinate                 27
# Name: 328, dtype: object
# Text              sixthree69j
# ContainsDigits           True
# Coordinate                 69
# Name: 329, dtype: object
# Text               24l
# ContainsDigits    True
# Coordinate          24
# Name: 330, dtype: object
# Text              cpzltvslq9nfhcv
# ContainsDigits              False
# Coordinate                     99
# Name: 331, dtype: object
# Text              six46eightsixsixbblvjjkvntmm
# ContainsDigits                            True
# Coordinate                                  46
# Name: 332, dtype: object
# Text              7five3
# ContainsDigits      True
# Coordinate            73
# Name: 333, dtype: object
# Text              six2three
# ContainsDigits        False
# Coordinate               22
# Name: 334, dtype: object
# Text              seven2xxxhhjnl53sixjtgbnvh6
# ContainsDigits                           True
# ...
# Coordinate                      18
# Name: 888, dtype: object
# Text              threeeightsix36xvtm
# ContainsDigits                   True
# Coordinate                         36
# Name: 889, dtype: object
# Text              nine5eightczhsix3twoprztckvb
# ContainsDigits                            True
# Coordinate                                  53
# Name: 890, dtype: object
# Text              pxrsgpszonepdjvxcblqzkr61seven11
# ContainsDigits                                True
# Coordinate                                      61
# Name: 891, dtype: object
# Text              5sevenonesevensix4six1dvhrx
# ContainsDigits                           True
# Coordinate                                 51
# Name: 892, dtype: object
# Text              cdxnbseven9qsevenvbv4
# ContainsDigits                     True
# Coordinate                           94
# Name: 893, dtype: object
# Text              sixlgjt3
# ContainsDigits       False
# Coordinate              33
# Name: 894, dtype: object
# Text              dhpxhpbkq3lc6rkjlpdz4five5pctfzsplrf
# ContainsDigits                                    True
# Coordinate                                          35
# Name: 895, dtype: object
# Text              1kmsmgjpmkqfckr
# ContainsDigits              False
# Coordinate                     11
# Name: 896, dtype: object
# Text              sixeight1k44
# ContainsDigits            True
# Coordinate                  14
# Name: 897, dtype: object
# Text              52qdfp1b8
# ContainsDigits         True
# Coordinate               58
# Name: 898, dtype: object
# Text              86fourthree42
# ContainsDigits             True
# Coordinate                   82
# Name: 899, dtype: object
# Text              six2fourpjtsvskrxtmgxnj2one3dn
# ContainsDigits                              True
# Coordinate                                    23
# Name: 900, dtype: object
# Text              rjtfqxvfm88seventhreeeighttwo
# ContainsDigits                             True
# Coordinate                                   88
# Name: 901, dtype: object
# Text              fivepgfvxcds64sevenhg
# ContainsDigits                     True
# Coordinate                           64
# Name: 902, dtype: object
# Text              glvhcrgbtphxfsfourthreerqhjxpzone5gh
# ContainsDigits                                   False
# Coordinate                                          55
# Name: 903, dtype: object
# Text              1sevenone34
# ContainsDigits           True
# Coordinate                 14
# Name: 904, dtype: object
# Text              689five9ninetwotwo4
# ContainsDigits                   True
# Coordinate                         64
# Name: 905, dtype: object
# Text              6two92sixjb1cbhmrq
# ContainsDigits                  True
# Coordinate                        61
# Name: 906, dtype: object
# Text              fiverrvllhbgcsskh2
# ContainsDigits                 False
# Coordinate                        22
# Name: 907, dtype: object
# Text              foureight6fhtx1five8eight
# ContainsDigits                         True
# Coordinate                               68
# Name: 908, dtype: object
# Text              pqvvjkhtxkxcjkrf9mn
# ContainsDigits                  False
# Coordinate                         99
# Name: 909, dtype: object
# Text              threefive2hs6one6jhkbdh
# ContainsDigits                       True
# Coordinate                             26
# Name: 910, dtype: object
# Text              twoninefzflrqqzvp2xnr8
# ContainsDigits                      True
# Coordinate                            28
# Name: 911, dtype: object
# Text              one51
# ContainsDigits     True
# Coordinate           51
# Name: 912, dtype: object
# Text              7bjpnfsgpszrfk5fourthreebvvn
# ContainsDigits                            True
# Coordinate                                  75
# Name: 913, dtype: object
# Text              six74
# ContainsDigits     True
# Coordinate           74
# Name: 914, dtype: object
# Text              twozcgbrrhxcpznx9dlcgdchpndcdc
# ContainsDigits                             False
# Coordinate                                    99
# Name: 915, dtype: object
# Text              nines566
# ContainsDigits        True
# Coordinate              56
# Name: 916, dtype: object
# Text              one72zshxlsix
# ContainsDigits             True
# Coordinate                   72
# Name: 917, dtype: object
# Text              vseven4fouronenine6
# ContainsDigits                   True
# Coordinate                         46
# Name: 918, dtype: object
# Text              7four1nine2threekzjbs4
# ContainsDigits                      True
# Coordinate                            74
# Name: 919, dtype: object
# Text              onecq3four
# ContainsDigits         False
# Coordinate                33
# Name: 920, dtype: object
# Text              twodcrx8
# ContainsDigits       False
# Coordinate              88
# Name: 921, dtype: object
# Text              four35sjjhpfftzsixfqctsfonefiveseven
# ContainsDigits                                    True
# Coordinate                                          35
# Name: 922, dtype: object
# Text              sxqnssjtwothree2
# ContainsDigits               False
# Coordinate                      22
# Name: 923, dtype: object
# Text              8fdpjrztwoseventwo5rmqvoneeight
# ContainsDigits                               True
# Coordinate                                     85
# Name: 924, dtype: object
# Text              pjlbnl3rg3shchseven
# ContainsDigits                   True
# Coordinate                         33
# Name: 925, dtype: object
# Text              zdcrnpddv2
# ContainsDigits         False
# Coordinate                22
# Name: 926, dtype: object
# Text              eight2foureighttgjcxtf2
# ContainsDigits                       True
# Coordinate                             22
# Name: 927, dtype: object
# Text              ghhxlxqttvonerh96715twonectr
# ContainsDigits                            True
# Coordinate                                  95
# Name: 928, dtype: object
# Text              9hmfxxrsdbsixbtwo7sevensix
# ContainsDigits                          True
# Coordinate                                97
# Name: 929, dtype: object
# Text              32ghjqjfp7three4one
# ContainsDigits                   True
# Coordinate                         34
# Name: 930, dtype: object
# Text               197
# ContainsDigits    True
# Coordinate          17
# Name: 931, dtype: object
# Text              twon8five2
# ContainsDigits          True
# Coordinate                82
# Name: 932, dtype: object
# Text              vtwobrlhqsq1twothreesixthree
# ContainsDigits                           False
# Coordinate                                  11
# Name: 933, dtype: object
# Text              xbdxninefour8seven
# ContainsDigits                 False
# Coordinate                        88
# Name: 934, dtype: object
# Text              five39
# ContainsDigits      True
# Coordinate            39
# Name: 935, dtype: object
# Text              621eightsix
# ContainsDigits           True
# Coordinate                 61
# Name: 936, dtype: object
# Text              21fvdd11tsdzhjspzld4
# ContainsDigits                    True
# Coordinate                          24
# Name: 937, dtype: object
# Text              7seventwoeightfpnkhxmvc
# ContainsDigits                      False
# Coordinate                             77
# Name: 938, dtype: object
# Text              96sjrcvzxsevenfqt4seven9
# ContainsDigits                        True
# Coordinate                              99
# Name: 939, dtype: object
# Text              xzxmtsrhbfivenineninerxgcrx9one
# ContainsDigits                              False
# Coordinate                                     99
# Name: 940, dtype: object
# Text              5pzgmrgrg2kdgl9one
# ContainsDigits                  True
# Coordinate                        59
# Name: 941, dtype: object
# Text              lqzmttxcpp7cnfstnhtglzhssntjmsixseven6six
# ContainsDigits                                         True
# Coordinate                                               76
# Name: 942, dtype: object
# Text              two711
# ContainsDigits      True
# Coordinate            71
# Name: 943, dtype: object
# Text              6onevjnvmkkx
# ContainsDigits           False
# Coordinate                  66
# Name: 944, dtype: object
# Text              eight7dbmznvztwo
# ContainsDigits               False
# Coordinate                      77
# Name: 945, dtype: object
# Text              9mlpltkt3
# ContainsDigits         True
# Coordinate               93
# Name: 946, dtype: object
# Text              7ninenine4tpjbsbtsgzttlgrtnfvr91four
# ContainsDigits                                    True
# Coordinate                                          71
# Name: 947, dtype: object
# Text              foursevenq7
# ContainsDigits          False
# Coordinate                 77
# Name: 948, dtype: object
# Text              six1sgtbsmgft9
# ContainsDigits              True
# Coordinate                    19
# Name: 949, dtype: object
# Text              nineone28fourjtwo8
# ContainsDigits                  True
# Coordinate                        28
# Name: 950, dtype: object
# Text              76threebgqvh6lfbkdmfvcthreeone3
# ContainsDigits                               True
# Coordinate                                     73
# Name: 951, dtype: object
# Text              13cvtpqnmbv
# ContainsDigits           True
# Coordinate                 13
# Name: 952, dtype: object
# Text              1sevenzjhtfpbfb73rccvtnmtthree7
# ContainsDigits                               True
# Coordinate                                     17
# Name: 953, dtype: object
# Text              4xhvshhtmxx7sevenf9
# ContainsDigits                   True
# Coordinate                         49
# Name: 954, dtype: object
# Text              8one1
# ContainsDigits     True
# Coordinate           81
# Name: 955, dtype: object
# Text              931fivetmdmsrrmfxrplkfvfourthreeeight
# ContainsDigits                                     True
# Coordinate                                           91
# Name: 956, dtype: object
# Text              qzbthffhlg2
# ContainsDigits          False
# Coordinate                 22
# Name: 957, dtype: object
# Text              one4eight33
# ContainsDigits           True
# Coordinate                 43
# Name: 958, dtype: object
# Text              qfjqt9jlcthreeqkfdpfiveeight8scfnlj
# ContainsDigits                                   True
# Coordinate                                         98
# Name: 959, dtype: object
# Text              fvczqbtsix2bxkgsnsix5nine7
# ContainsDigits                          True
# Coordinate                                27
# Name: 960, dtype: object
# Text              9qxnvlnine2phnlqzninefive
# ContainsDigits                         True
# Coordinate                               92
# Name: 961, dtype: object
# Text              tszjsxbsixtwoeight62ffjtdnxxtwofive
# ContainsDigits                                   True
# Coordinate                                         62
# Name: 962, dtype: object
# Text              one2skxg
# ContainsDigits       False
# Coordinate              22
# Name: 963, dtype: object
# Text              five5onexzgzkjvtqrfourfive
# ContainsDigits                         False
# Coordinate                                55
# Name: 964, dtype: object
# Text              twozsxzqtrqbxqqqsbcvfpgdcdpttwo1six
# ContainsDigits                                  False
# Coordinate                                         11
# Name: 965, dtype: object
# Text              8mqkgptxsixhqmbqshcl
# ContainsDigits                   False
# Coordinate                          88
# Name: 966, dtype: object
# Text              lsdlsxrhdqthreesix2sevenchjxvmsjpvrnpcblgmsix
# ContainsDigits                                            False
# Coordinate                                                   22
# Name: 967, dtype: object
# Text              gngrfrhbxhqkxs5fourr8three4
# ContainsDigits                           True
# Coordinate                                 54
# Name: 968, dtype: object
# Text              jlzszzz9one
# ContainsDigits          False
# Coordinate                 99
# Name: 969, dtype: object
# Text              twozrbjkjpzseventwonine8dbmfdjcb
# ContainsDigits                               False
# Coordinate                                      88
# Name: 970, dtype: object
# Text              3nine36ppqone4czxvkxjzv
# ContainsDigits                       True
# Coordinate                             34
# Name: 971, dtype: object
# Text              ld6eightseven6twosix
# ContainsDigits                    True
# Coordinate                          66
# Name: 972, dtype: object
# Text              1jnbfive
# ContainsDigits       False
# Coordinate              11
# Name: 973, dtype: object
# Text              7threeglmcdhpvq4723fivethree
# ContainsDigits                            True
# Coordinate                                  73
# Name: 974, dtype: object
# Text              seven148oneightd
# ContainsDigits                True
# Coordinate                      18
# Name: 975, dtype: object
# Text              sevensevenseven6sixtwosix21
# ContainsDigits                           True
# Coordinate                                 61
# Name: 976, dtype: object
# Text              8twojhdkdrcqgmclqlldv6sevenonedjthcz
# ContainsDigits                                    True
# Coordinate                                          86
# Name: 977, dtype: object
# Text              ninesevenggsjbpt5ttlrq
# ContainsDigits                     False
# Coordinate                            55
# Name: 978, dtype: object
# Text              59sixfivefive
# ContainsDigits             True
# Coordinate                   59
# Name: 979, dtype: object
# Text              eight9bsmcgkseventhree66qmgpkkxnpm
# ContainsDigits                                  True
# Coordinate                                        96
# Name: 980, dtype: object
# Text              fourthree73fiveseven
# ContainsDigits                    True
# Coordinate                          73
# Name: 981, dtype: object
# Text              9five9six8threet
# ContainsDigits                True
# Coordinate                      98
# Name: 982, dtype: object
# Text              3eight44
# ContainsDigits        True
# Coordinate              34
# Name: 983, dtype: object
# Text              dlcbjflsix5ttvjdxzzeightcffrtfjcjpxtwostrdc
# ContainsDigits                                          False
# Coordinate                                                 55
# Name: 984, dtype: object
# Text              fiveone645fivellfcmqqmnine
# ContainsDigits                          True
# Coordinate                                65
# Name: 985, dtype: object
# Text              hxdtshfive115tfvrzqhgftwojtjrcshgtq
# ContainsDigits                                   True
# Coordinate                                         15
# Name: 986, dtype: object
# Text              6nqrfrhv17jdxpfmmdt4five
# ContainsDigits                        True
# Coordinate                              64
# Name: 987, dtype: object
# Text              sevenxtpjxnrr1
# ContainsDigits             False
# Coordinate                    11
# Name: 988, dtype: object
# Text              krzkthreegjnqrfbsdrkqptd33rsvrzvvffqhreight
# ContainsDigits                                           True
# Coordinate                                                 33
# Name: 989, dtype: object
# Text              472ggfive56hgnvz
# ContainsDigits                True
# Coordinate                      46
# Name: 990, dtype: object
# Text              12tkpchqtnine
# ContainsDigits             True
# Coordinate                   12
# Name: 991, dtype: object
# Text              vdbsctv6eightth82
# ContainsDigits                 True
# Coordinate                       62
# Name: 992, dtype: object
# Text              fivetngxlttf4
# ContainsDigits            False
# Coordinate                   44
# Name: 993, dtype: object
# Text               5nss
# ContainsDigits    False
# Coordinate           55
# Name: 994, dtype: object
# Text              5onesixsevenphxtmlqhzfcjxrknpv
# ContainsDigits                             False
# Coordinate                                    55
# Name: 995, dtype: object
# Text              gldsixrhss186seven6
# ContainsDigits                   True
# Coordinate                         16
# Name: 996, dtype: object
# Text              gnpksz4
# ContainsDigits      False
# Coordinate             44
# Name: 997, dtype: object
# Text              4919
# ContainsDigits    True
# Coordinate          49
# Name: 998, dtype: object
# Text              pbc19
# ContainsDigits     True
# Coordinate           19
# Name: 999, dtype: object

# %% [markdown]
# The third entry is incorrect already. The text: xvtfhkm8c9 contains at least two digits, but the corresponding entry in the column is False. Time to find out why the regex failed.

# %%
df['Text'].str.contains(r'\d{2,}')[13]
# Out:
# False

# %%
df["Text"]
# Out:
# 0                        gsjgklneight6zqfz
# 1                   7one718onegfqtdbtxfcmd
# 2                               xvtfhkm8c9
# 3                                  914two8
# 4      vxzzvdhfqfsix83c1ttvbbstxgdrkfcnmm3
#                       ...
# 995         5onesixsevenphxtmlqhzfcjxrknpv
# 996                    gldsixrhss186seven6
# 997                                gnpksz4
# 998                                   4919
# 999                                  pbc19
# Name: Text, Length: 1000, dtype: object

# %% [markdown]
# I think I got it. The regex fails instances when the two digits are not next to each other, and classifies them as false. I will have to correct this. I'm thinking about replacing the regex with simply checking how long the digits list is.

# %%
df.Coordinate.sum()
# Out:
# 55108
